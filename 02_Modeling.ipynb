# %% [markdown]
# <center><span style="color:#b30000;font-size:35px;"><strong>Modeling Phase</strong></span></center>

# %% [markdown]
# <span style="color:#2929a3;font-size:20px;">Import Libraries</span>

# %%
import pandas as pd
import numpy as np
import plotly.express as px
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler, LabelEncoder, OneHotEncoder
from category_encoders import BinaryEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import KNNImputer
from sklearn.model_selection import cross_validate
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, VotingRegressor , AdaBoostRegressor
from xgboost import XGBRegressor

# %% [markdown]
# <span style="color:#2929a3;font-size:20px;">Read Dataset</span>

# %%
df = pd.read_pickle('Data/df_cleaned.pkl')

# %% [markdown]
# <span style="color:#2929a3;font-size:20px;">Show Sample of The Dataset </span>

# %%
df.sample(5)
# Out:
#           Airline Date_of_Journey    Source Destination  \
# 3072    Air India      2019-04-01   Kolkata    Banglore
# 1907     Air Asia      2019-06-01     Delhi      Cochin
# 189   Jet Airways      2019-03-12  Banglore   New Delhi
# 2016       IndiGo      2019-03-01  Banglore   New Delhi
# 9285  Jet Airways      2019-05-21   Kolkata    Banglore
#
#                       Route  Dep_Time Arrival_Time  Duration  Total_Stops  \
# 3072  CCU → BOM → HBX → BLR  16:50:00     18:20:00      1530            2
# 1907        DEL → BLR → COK  20:45:00     07:10:00       625            1
# 189         BLR → BOM → DEL  20:35:00     15:15:00      1120            1
# 2016              BLR → DEL  18:55:00     21:45:00       170            0
# 9285        CCU → BOM → BLR  14:05:00     08:15:00      1090            1
#
#                   Additional_Info  Price Journey_Day Journey_DayName  \
# 3072                      No info   7893           1          Monday
# 1907                      No info  11410           1        Saturday
# 189   In-flight meal not included  11087          12         Tuesday
# 2016                      No info  14306           1          Friday
# 9285  In-flight meal not included   9663          21         Tuesday
#
#      Journey_MonthName Arrival_Date
# 3072             April   2019-04-02
# 1907              June   2019-06-02
# 189              March   2019-03-13
# 2016             March   2019-03-01
# 9285               May   2019-05-22

# %% [markdown]
# <span style="color:#2929a3;font-size:20px;">Show Shape of Dataset </span>

# %%
df.shape
# Out:
# (10169, 15)

# %% [markdown]
# <span style="color:#2929a3;font-size:20px;">Check Null Values </span>

# %%
df.isnull().sum()
# Out:
# Airline              0
# Date_of_Journey      0
# Source               0
# Destination          0
# Route                0
# Dep_Time             0
# Arrival_Time         0
# Duration             0
# Total_Stops          0
# Additional_Info      0
# Price                0
# Journey_Day          0
# Journey_DayName      0
# Journey_MonthName    0
# Arrival_Date         0
# dtype: int64

# %% [markdown]
# <span style="color:#2929a3;font-size:20px;">Keep Only Important Columns </span>

# %%
df = df[['Airline','Source','Destination','Route','Duration','Journey_Day','Journey_MonthName','Price']]

# %% [markdown]
# <span style="color:#2929a3;font-size:20px;">Check Duplications </span>

# %%
df.duplicated().sum()
# Out:
# 782

# %%
## Drop Duplicates
df.drop_duplicates(inplace=True)

# %%
## Reset Index
df.reset_index(drop=True, inplace=True)

# %%
## Check Shape
df.shape
# Out:
# (9387, 8)

# %% [markdown]
# <span style="color:#2929a3;font-size:20px;">Convert "Journey_Day" and "Journey_MonthName" to Numeric </span>

# %%
df['Journey_Day'] = df['Journey_Day'].astype(int)

# %%
df['Journey_MonthName'] = df['Journey_MonthName'].replace({'March':3, 'April':4, 'May':5, 'June':6})

# %% [markdown]
# ### Note
# #### I transformed the day and month features to numeric values to help the model capture the price changes that happened over the 4 months

# %% [markdown]
# <span style="color:#2929a3;font-size:20px;">Calculate the Log of the "Price" </span>

# %%
px.histogram(data_frame=df, x='Price', title='Price Distribution')
# Out:
# <div>                            <div id="9f4cd4d9-4622-4a0b-b462-de5eb4c4b211" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9f4cd4d9-4622-4a0b-b462-de5eb4c4b211")) {                    Plotly.newPlot(                        "9f4cd4d9-4622-4a0b-b462-de5eb4c4b211",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Price=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[7662,13882,6218,13302,3873,11087,22270,11087,8625,8907,4174,4667,9663,4804,14011,5830,10262,13381,12898,19495,3943,4823,7757,13292,8238,7682,4668,3687,3687,13227,4423,10919,12373,5894,4649,6245,19225,14924,9646,8714,12373,3383,13062,3527,3943,4667,6117,11150,7202,12121,3943,4483,14231,17345,7414,8073,12395,8366,5117,12524,7191,3687,5894,5403,3625,10861,6297,5678,10791,12819,6893,7240,3898,4049,10262,3332,10844,7229,13941,5894,10197,13712,5636,13014,7064,10703,9646,17057,13817,13748,4880,3540,3257,6478,8040,14300,14781,14939,10262,6528,6121,13029,11421,7574,11596,15129,5780,9397,17024,5281,10348,12677,15147,4668,15554,3971,3100,9663,27430,3540,10676,13044,14388,3943,3597,5932,10262,6216,4804,14067,15129,13376,10441,4030,17024,13017,6686,5636,6442,9486,10844,15318,5117,6147,7005,3873,9270,3898,14781,8586,10697,14300,8855,10844,17024,9314,4777,7662,6442,5264,12898,6092,3311,6540,3419,5177,8246,14676,13587,9663,13044,5073,9345,9663,14277,10262,5678,13727,9663,3858,4812,5775,10539,4804,3383,8738,7165,6412,8016,11087,3543,12471,10262,4441,12537,10091,6961,5013,6934,10877,7229,7048,4878,10844,3943,5583,9646,7677,6842,4995,9555,4077,7229,12192,5911,8372,4995,14323,13014,13591,3943,1965,4995,14641,4460,10191,13843,6349,4409,17024,13727,8855,12524,13555,10844,13587,3543,4842,3943,10577,6979,11982,5264,8001,10651,10844,6601,6587,3173,5228,5769,14714,13014,3359,6722,4462,6171,12303,7695,5684,8366,19630,13502,14781,6513,9929,18275,4487,2754,2575,8224,8991,5000,8529,14042,4030,10844,4804,7308,4823,10262,12898,12778,14871,8708,10844,4129,4804,7229,7832,3859,9001,4878,2754,4668,5216,10368,8146,12242,9134,10939,11753,4174,10844,14714,9899,14871,7295,13465,3543,7198,10262,4148,8016,10262,3841,11507,14781,16079,12898,15353,7303,6197,8996,6528,4239,4148,3971,5192,9483,18804,5201,16079,7229,6795,10953,15965,9968,4804,16079,11507,11542,7229,4544,6496,4804,13439,6540,4591,4437,6151,7754,10262,8016,4781,4668,14594,14231,8425,9646,7295,5162,6860,6216,5192,4823,3919,2754,9315,11667,6224,13349,15603,15129,4823,8452,12524,3384,10262,1965,4804,16079,13292,6751,8669,14871,12898,3919,36983,10741,11432,11087,13292,7631,13381,13731,11911,4591,14848,8266,12392,13044,12898,12242,3943,11105,14388,13014,15411,16289,6442,10844,5678,6906,3543,14714,14323,3971,8452,5403,13727,12639,5198,4878,12373,8552,6741,6481,7354,5228,10844,6347,5013,9663,4823,13381,3543,9663,7064,10262,13013,15339,4937,6818,10441,5177,3858,6534,6795,9736,7229,4957,7648,3873,14388,5618,7408,13774,4668,8669,6316,12583,7923,7378,4878,10844,7229,6297,8529,13727,6643,10197,4911,6482,26890,3717,3597,10846,14069,5177,14641,6442,5704,9663,14714,5406,8610,14237,4823,2227,12373,8372,17024,3100,14053,3540,9345,10368,26890,5755,7832,14388,8839,22096,3687,9627,13542,4423,8899,5583,6752,10991,12898,12898,3398,5201,13873,7384,10262,10031,12384,7757,17261,7298,7229,4174,5699,4880,15284,13759,16092,4392,10262,3841,5048,11096,5073,19828,3739,7229,8610,6216,6961,10703,14151,8586,4488,7408,5443,10539,7723,15411,7229,4804,4050,14151,4957,7591,11134,6600,4966,15481,5515,14714,4959,7229,6094,4409,9794,5678,6442,4878,12446,9134,8586,7229,6144,6961,10844,3597,7139,25139,10368,5117,9211,4174,10786,9134,13376,10844,3807,9663,12373,4991,6745,10262,6540,3873,15554,4804,7 ...

# %%
df['Price'] = df['Price'].apply(lambda x:np.log10(x))

# %%
px.histogram(data_frame=df, x='Price', title='Log of Price Distribution')
# Out:
# <div>                            <div id="f5b77c51-7bc9-43c1-ae6c-5ebef739b2f0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f5b77c51-7bc9-43c1-ae6c-5ebef739b2f0")) {                    Plotly.newPlot(                        "f5b77c51-7bc9-43c1-ae6c-5ebef739b2f0",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Price=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[3.8843421476470588,4.142452040066341,3.793650717707173,4.1239169434981315,3.588047496986083,4.0448140475286385,4.3477202170340385,4.0448140475286385,3.935759103745312,3.949731452315707,3.620552444729435,3.669037800885156,3.985111979539354,3.6816029987308685,4.14646913307187,3.765668554759014,4.011232010319366,4.126488570700374,4.110522372601323,4.289923239524004,3.5958267770732233,3.6833172619218826,3.889693791444185,4.123590332606674,3.915821787620399,3.885474302829157,3.6691308473733324,3.5666731376061165,3.5666731376061165,4.121461353545985,3.6457169393696036,4.0381828659906605,4.09247501292598,3.7704101315139065,3.667359546183087,3.7955324427101544,4.2838663484734685,4.173885240368792,3.984347257585864,3.940217555599735,4.09247501292598,3.5293019977879805,4.116009679424738,3.5474054596674898,3.5958267770732233,3.669037800885156,3.7865384804978026,4.047274867384179,3.8574531170352664,4.083538451230139,3.5958267770732233,3.651568738865792,4.1532354186522955,4.2391743041780785,3.8700525816935447,3.907034952483417,4.093246531103841,3.9225178602446116,3.7090154169721172,4.097743058944878,3.8567892887533164,3.5666731376061165,3.7704101315139065,3.732634967539196,3.5593080109070123,4.035869813695553,3.7991336933020627,3.7541953881898382,4.0330616925381735,4.107854147536859,3.8384082784941866,3.859738566197147,3.5908418347816027,3.6073477767684134,4.011232010319366,3.52270499273475,4.035189508908448,3.8590782247469693,4.144293927198531,3.7704101315139065,4.008472419302722,4.137100804579123,3.750970984437319,4.1144108023978365,3.8490506905695123,4.029505525426577,3.984347257585864,4.231902649456643,4.140413757591074,4.138239523465188,3.6884198220027105,3.5490032620257876,3.512817758564873,3.811440943674158,3.905256048748451,4.155336037465061,4.169703816994572,4.17432152726404,4.011232010319366,3.8147801457458046,3.7868223794991875,4.114911084081892,4.05770413153403,3.8793253007848074,4.06430820668296,4.179810222878796,3.761927838420529,3.972989226855349,4.231061610614955,3.7227161674884948,4.014856420044506,4.103016490328315,4.180326625415149,3.6691308473733324,4.191842094619106,3.598899887063883,3.4913616938342726,3.985111979539354,4.438225807604529,3.5490032620257876,4.02840856511547,4.115410790133919,4.158000429146473,3.5958267770732233,3.5559404378185113,3.7732011423563443,4.011232010319366,3.793511005792858,3.6816029987308685,4.148201487458512,4.179810222878796,4.126326260094941,4.018742095762382,3.6053050461411096,4.231061610614955,4.114510904848874,3.82516637225655,3.750970984437319,3.8090207204836726,3.9770831203158528,4.035189508908448,4.185202065187894,3.7090154169721172,3.7886632131208575,3.8454081396217936,3.588047496986083,3.967079734144497,3.5908418347816027,4.169703816994572,3.93379088414342,4.029261995804175,4.155336037465061,3.9471885655260937,4.035189508908448,4.231061610614955,3.9691362335967124,3.679155241283354,3.8843421476470588,3.8090207204836726,3.721315880605899,4.110522372601323,3.784759894664005,3.5199591807520685,3.815577748324267,3.5338991007965945,3.714078164981856,3.9162433304653397,4.16660770308391,4.133123575402619,3.985111979539354,4.115410790133919,3.7052648623174043,3.970579305714851,3.985111979539354,4.15463695951842,4.011232010319366,3.754195 ...

# %% [markdown]
# <span style="color:#2929a3;font-size:20px;">Split Data to X and Y </span>

# %%
X = df.drop('Price', axis=1)
Y = df['Price']

# %% [markdown]
# <span style="color:#2929a3;font-size:20px;">Create Preprocessor Column Transformer</span>

# %%
preprocessor = ColumnTransformer(transformers=[('Encoder',BinaryEncoder(),['Airline','Source','Destination','Route','Journey_MonthName'])], remainder='passthrough')

# %% [markdown]
# <span style="color:#2929a3;font-size:20px;">Model Selection Process</span>

# %%
Models = []
Models.append(('Linear Regression',LinearRegression()))
Models.append(('Lasso',Lasso()))
Models.append(('Ridge',Ridge()))
Models.append(('KNN',KNeighborsRegressor()))
Models.append(('SVM',SVR()))
Models.append(('Decision Tree',DecisionTreeRegressor()))
Models.append(('Random Forest',RandomForestRegressor()))
Models.append(('XGBoost',XGBRegressor()))
Models.append(('Adaptive Boosting',AdaBoostRegressor()))

# %%
for model in Models:
    steps = []
    steps.append(('Preprocessor',preprocessor))
    steps.append(('Scaler',RobustScaler()))
    steps.append(model)
    pipeline = Pipeline(steps=steps)
    res = cross_validate(pipeline, X, Y, cv=5, scoring='r2', return_train_score=True)
    print(f"{model[0]} Train R2-Score is {res['train_score'].mean()}")
    print(f"{model[0]} Test R2-Score is {res['test_score'].mean()}")
    print('*' * 50)
# Out:
# Linear Regression Train R2-Score is 0.5724219705033403
# Linear Regression Test R2-Score is 0.5622442459775847
# **************************************************
# Lasso Train R2-Score is 0.0
# Lasso Test R2-Score is -0.001143877764228174
# **************************************************
# Ridge Train R2-Score is 0.5724552235005559
# Ridge Test R2-Score is 0.5625157059477282
# **************************************************
# KNN Train R2-Score is 0.887969440237773
# KNN Test R2-Score is 0.829645899978243
# **************************************************
# SVM Train R2-Score is 0.8408925082074417
# SVM Test R2-Score is 0.8257739584068062
# **************************************************
# Decision Tree Train R2-Score is 0.9567787158257894
# Decision Tree Test R2-Score is 0.763112292922427
# **************************************************
# Random Forest Train R2-Score is 0.947681256060165
# Random Forest Test R2-Score is 0.8329573369685519
# **************************************************
# XGBoost Train R2-Score is 0.9249303925481662
# XGBoost Test R2-Score is 0.8718799409761931
# **************************************************
# Adaptive Boosting Train R2-Score is 0.6405203499646677
# Adaptive Boosting Test R2-Score is 0.6347433407114652
# **************************************************

# %% [markdown]
# <span style="color:#2929a3;font-size:20px;">Create XGBoost Pipeline</span>

# %%
steps = []
steps.append(('Preprocessor', preprocessor))
steps.append(('Scaler',RobustScaler()))
steps.append(('Model',XGBRegressor()))
pipeline = Pipeline(steps = steps)

# %% [markdown]
# <span style="color:#2929a3;font-size:20px;">Hyperparameter Tuning</span>

# %%
from sklearn.model_selection import GridSearchCV

# %%
param = [{
    'Model__n_estimators':[135,140,145,150],
    'Model__max_depth':[4,5,10],
    'Model__max_leaves':[1,2,3]
}]

# %%
grid = GridSearchCV(pipeline, param_grid=param, cv=5, scoring='r2', return_train_score=True)

# %%
grid.fit(X,Y)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('Preprocessor',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('Encoder',
#                                                                          BinaryEncoder(),
#                                                                          ['Airline',
#                                                                           'Source',
#                                                                           'Destination',
#                                                                           'Route',
#                                                                           'Journey_MonthName'])])),
#                                        ('Scaler', RobustScaler()),
#                                        ('Model',
#                                         XGBRegressor(base_score=None,
#                                                      booster=None,
#                                                      callbacks=None,
#                                                      colsample_bylevel=None,
#                                                      colsample_bynode=None,
#                                                      col...
#                                                      max_delta_step=None,
#                                                      max_depth=None,
#                                                      max_leaves=None,
#                                                      min_child_weight=None,
#                                                      missing=nan,
#                                                      monotone_constraints=None,
#                                                      n_estimators=100,
#                                                      n_jobs=None,
#                                                      num_parallel_tree=None,
#                                                      predictor=None,
#                                                      random_state=None, ...))]),
#              param_grid=[{'Model__max_depth': [4, 5, 10],
#                           'Model__max_leaves': [1, 2, 3],
#                           'Model__n_estimators': [135, 140, 145, 150]}],
#              return_train_score=True, scoring='r2')

# %%
grid.cv_results_['mean_train_score'][grid.best_index_]
# Out:
# 0.9166752795091696

# %%
grid.cv_results_['mean_test_score'][grid.best_index_]
# Out:
# 0.8743749841903551

# %%
grid.best_params_
# Out:
# {'Model__max_depth': 5, 'Model__max_leaves': 1, 'Model__n_estimators': 135}

# %%
Final_Model = grid.best_estimator_

# %%
Final_Model.fit(X,Y)
# Out:
# Pipeline(steps=[('Preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('Encoder', BinaryEncoder(),
#                                                   ['Airline', 'Source',
#                                                    'Destination', 'Route',
#                                                    'Journey_MonthName'])])),
#                 ('Scaler', RobustScaler()),
#                 ('Model',
#                  XGBRegressor(base_score=None, booster=None, callbacks=None,
#                               colsample_bylevel=None, colsample_bynode=None,
#                               colsample_bytree=None, early_sto...
#                               feature_types=None, gamma=None, gpu_id=None,
#                               grow_policy=None, importance_type=None,
#                               interaction_constraints=None, learning_rate=None,
#                               max_bin=None, max_cat_threshold=None,
#                               max_cat_to_onehot=None, max_delta_step=None,
#                               max_depth=5, max_leaves=1, min_child_weight=None,
#                               missing=nan, monotone_constraints=None,
#                               n_estimators=135, n_jobs=None,
#                               num_parallel_tree=None, predictor=None,
#                               random_state=None, ...))])

# %% [markdown]
# <span style="color:#2929a3;font-size:20px;">Dump the Final Model</span>

# %%
import joblib

# %%
joblib.dump(Final_Model, 'Data/Final_Model.pkl')
# Out:
# ['Data/Final_Model.pkl']

# %% [markdown]
# <span style="color:#2929a3;font-size:20px;">Dump the Inputs</span>

# %%
## Original Dict
Inputs_dict = {}

# %%
## Append Name of columns
Inputs_dict['inputs'] = df.columns.tolist()

# %%
## Append Unique Values of each Categorical Feature
Inputs_dict['Airlines'] = df['Airline'].unique().tolist()
Inputs_dict['Source'] = df['Source'].unique().tolist()
Inputs_dict['Destination'] = df['Destination'].unique().tolist()

## Create 2 sub dict inside original dict
Inputs_dict['Source_Destination'] = {}
Inputs_dict['Destination_Route'] = {}

# %%
## Append Destinations of each Source
Inputs_dict['Source_Destination']['Chennai'] = ['Kolkata']
Inputs_dict['Source_Destination']['Kolkata'] = ['Banglore']
Inputs_dict['Source_Destination']['Banglore'] = ['Delhi','New Delhi']
Inputs_dict['Source_Destination']['Delhi'] = ['Cochin']
Inputs_dict['Source_Destination']['Mumbai'] = ['Hyderabad']

# %%
## Append Routes of each Destination
Inputs_dict['Destination_Route']['Kolkata'] = df[df['Destination'] == 'Kolkata']['Route'].unique().tolist()
Inputs_dict['Destination_Route']['Banglore'] = df[df['Destination'] == 'Banglore']['Route'].unique().tolist()
Inputs_dict['Destination_Route']['Delhi'] = df[df['Destination'] == 'Delhi']['Route'].unique().tolist()
Inputs_dict['Destination_Route']['New Delhi'] = df[df['Destination'] == 'New Delhi']['Route'].unique().tolist()
Inputs_dict['Destination_Route']['Cochin'] = df[df['Destination'] == 'Cochin']['Route'].unique().tolist()
Inputs_dict['Destination_Route']['Hyderabad'] = df[df['Destination'] == 'Hyderabad']['Route'].unique().tolist()

# %%
## Dump Inputs Dict
joblib.dump(Inputs_dict, "Data/Inputs_dict.pkl")
# Out:
# ['Data/Inputs_dict.pkl']
